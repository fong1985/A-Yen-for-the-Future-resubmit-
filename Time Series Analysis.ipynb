# %%
import numpy as np
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Return Forecasting: Read Historical Daily Yen Futures Data
# In this notebook, you will load historical Dollar-Yen exchange rate futures data and apply time series analysis and modeling to determine whether there is any predictable behavior.

# %%
pwd
# Out:
# 'C:\\Users\\Michael\\FinTech Bootcamp\\week_10\\homework\\Starter_Code'

# %%
# Futures contract on the Yen-dollar exchange rate:
# This is the continuous chain of the futures contracts that are 1 month to expiration
yen_futures = pd.read_csv(
    Path("yen.csv"), index_col="Date", infer_datetime_format=True, parse_dates=True
)
yen_futures.head()
# Out:
#               Open    High     Low    Last  Change  Settle  Volume  \
# Date
# 1976-08-02  3398.0  3401.0  3398.0  3401.0     NaN  3401.0     2.0
# 1976-08-03  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
# 1976-08-04  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
# 1976-08-05  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
# 1976-08-06  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
#
#             Previous Day Open Interest
# Date
# 1976-08-02                         1.0
# 1976-08-03                         1.0
# 1976-08-04                         1.0
# 1976-08-05                         1.0
# 1976-08-06                         1.0

# %%
# Trim the dataset to begin on January 1st, 1990
yen_futures = yen_futures.loc["1990-01-01":, :]
yen_futures.head()
# Out:
#               Open    High     Low    Last  Change  Settle   Volume  \
# Date
# 1990-01-02  6954.0  6954.0  6835.0  6847.0     NaN  6847.0  48336.0
# 1990-01-03  6877.0  6910.0  6865.0  6887.0     NaN  6887.0  38206.0
# 1990-01-04  6937.0  7030.0  6924.0  7008.0     NaN  7008.0  49649.0
# 1990-01-05  6952.0  6985.0  6942.0  6950.0     NaN  6950.0  29944.0
# 1990-01-08  6936.0  6972.0  6936.0  6959.0     NaN  6959.0  19763.0
#
#             Previous Day Open Interest
# Date
# 1990-01-02                     51473.0
# 1990-01-03                     53860.0
# 1990-01-04                     55699.0
# 1990-01-05                     53111.0
# 1990-01-08                     52072.0

# %% [markdown]
#  # Return Forecasting: Initial Time-Series Plotting

# %% [markdown]
#  Start by plotting the "Settle" price. Do you see any patterns, long-term and/or short?

# %%
# Plot just the "Settle" column from the dataframe:
yen_futures.Settle.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Long Term Trends:
#
# The Yen Futures settlement prices show that investors flock to curreny in times of market volatility as seen in the sharp appreciation in the Yen during the Asian Financial Crsis in 1997 and also the 2008 financial crisis.
# This is due to the Yen's status as a premier funding currency.
#
# In a market of low interest rates in Japan during 2012, where rates were 0%, Yen futures appreicated due to investors deploying their cash instead of having to pay banks for their deposits.

# %% [markdown]
# ---

# %% [markdown]
# # Decomposition Using a Hodrick-Prescott Filter

# %% [markdown]
#  Using a Hodrick-Prescott Filter, decompose the Settle price into a trend and noise.

# %%
import statsmodels.api as sm

# Apply the Hodrick-Prescott Filter by decomposing the "Settle" price into two separate series:
ts_noise, ts_trend = sm.tsa.filters.hpfilter(yen_futures['Settle'])
ts_trend.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ts_noise.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Create a dataframe of just the settle price, and add columns for "noise" and "trend" series from above:
filtered_df = pd.DataFrame()
filtered_df["Noise"] = ts_noise
filtered_df["Trend"] = ts_trend
filtered_df["Price"] = yen_futures['Settle']
filtered_df
# Out:
#                 Noise        Trend   Price
# Date
# 1990-01-02 -61.503967  6908.503967  6847.0
# 1990-01-03 -21.799756  6908.799756  6887.0
# 1990-01-04  98.942896  6909.057104  7008.0
# 1990-01-05  40.776052  6909.223948  6950.0
# 1990-01-08  49.689938  6909.310062  6959.0
# ...               ...          ...     ...
# 2019-10-09  24.939247  9313.060753  9338.0
# 2019-10-10  -5.868559  9309.368559  9303.5
# 2019-10-11 -54.454594  9305.454594  9251.0
# 2019-10-14 -36.423060  9301.423060  9265.0
# 2019-10-15 -75.844123  9297.344123  9221.5
#
# [7515 rows x 3 columns]

# %%
# Plot the Settle Price vs. the Trend for 2015 to the present
filtered_df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Plot the Settle Noise
filtered_df.Price.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Forecasting Returns using an ARMA Model

# %% [markdown]
# Using futures Settle *Returns*, estimate an ARMA model
#
# 1. ARMA: Create an ARMA model and fit it to the returns data. Note: Set the AR and MA ("p" and "q") parameters to p=2 and q=1: order=(2, 1).
# 2. Output the ARMA summary table and take note of the p-values of the lags. Based on the p-values, is the model a good fit (p < 0.05)?
# 3. Plot the 5-day forecast of the forecasted returns (the results forecast from ARMA model)

# %%
# Create a series using "Settle" price percentage returns, drop any nan"s, and check the results:
# (Make sure to multiply the pct_change() results by 100)
# In this case, you may have to replace inf, -inf values with np.nan"s
returns = (yen_futures[["Settle"]].pct_change() * 100)
returns = returns.replace(-np.inf, np.nan).dropna()
returns.tail()
# Out:
#               Settle
# Date
# 2019-10-09 -0.410601
# 2019-10-10 -0.369458
# 2019-10-11 -0.564304
# 2019-10-14  0.151335
# 2019-10-15 -0.469509

# %%
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARMA

# Estimate and ARMA model using statsmodels (use order=(2, 1))
model = ARMA(returns.values, order=(2,1))

# Fit the model and assign it to a variable called results
results = model.fit()
# Out:
# C:\Users\Michael\anaconda3\envs\dev\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
# Output model summary results:
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                 7514
# Model:                     ARMA(2, 1)   Log Likelihood               -7894.071
# Method:                       css-mle   S.D. of innovations              0.692
# Date:                Mon, 13 Dec 2021   AIC                          15798.142
# Time:                        13:18:19   BIC                          15832.765
# Sample:                             0   HQIC                         15810.030
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0063      0.008      0.804      0.422      -0.009       0.022
# ar.L1.y       -0.3062      1.277     -0.240      0.811      -2.810       2.197
# ar.L2.y       -0.0019      0.019     -0.099      0.921      -0.040       0.036
# ...

# %% [markdown]
# Based on the above results the majority of the P Values are >0.05, indicating that this model is not a good fit.

# %%
# Plot the 5 Day Returns Forecast
pd.DataFrame(results.forecast(steps=5)[0]).plot(title="Yen 5 Day Return Forecast")
# Out:
# <AxesSubplot:title={'center':'Yen 5 Day Return Forecast'}>

# %% [markdown]
# ---

# %% [markdown]
# # Forecasting the Settle Price using an ARIMA Model

# %% [markdown]
#  1. Using the *raw* Yen **Settle Price**, estimate an ARIMA model.
#      1. Set P=5, D=1, and Q=1 in the model (e.g., ARIMA(df, order=(5,1,1))
#      2. P= # of Auto-Regressive Lags, D= # of Differences (this is usually =1), Q= # of Moving Average Lags
#  2. Output the ARIMA summary table and take note of the p-values of the lags. Based on the p-values, is the model a good fit (p < 0.05)?
#  3. Construct a 5 day forecast for the Settle Price. What does the model forecast will happen to the Japanese Yen in the near term?

# %%
from statsmodels.tsa.arima_model import ARIMA

# Estimate and ARIMA Model:
# Hint: ARIMA(df, order=(p, d, q))
model = ARIMA(yen_futures['Settle'], order=(5, 1, 1))

# Fit the model
results = model.fit()
# Out:
# C:\Users\Michael\anaconda3\envs\dev\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
# Output model summary results:
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:               D.Settle   No. Observations:                 7514
# Model:                 ARIMA(5, 1, 1)   Log Likelihood              -41944.619
# Method:                       css-mle   S.D. of innovations             64.281
# Date:                Mon, 13 Dec 2021   AIC                          83905.238
# Time:                        13:20:37   BIC                          83960.635
# Sample:                             1   HQIC                         83924.259
#
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.3161      0.700      0.452      0.652      -1.056       1.688
# ar.L1.D.Settle     0.2821      0.699      0.403      0.687      -1.088       1.653
# ...

# %% [markdown]
# Based on the above results the majority of the P Values are >0.05, indicating that this model is not a good fit.

# %%
# Plot the 5 Day Price Forecast
pd.DataFrame(results.forecast(steps=5)[0]).plot(title="5 day Futures Price Forecast")
# Out:
# <AxesSubplot:title={'center':'5 day Futures Price Forecast'}>

# %% [markdown]
# ---

# %% [markdown]
# # Volatility Forecasting with GARCH
#
# Rather than predicting returns, let's forecast near-term **volatility** of Japanese Yen futures returns. Being able to accurately predict volatility will be extremely useful if we want to trade in derivatives or quantify our maximum loss.
#
# Using futures Settle *Returns*, estimate an GARCH model
#
# 1. GARCH: Create an GARCH model and fit it to the returns data. Note: Set the parameters to p=2 and q=1: order=(2, 1).
# 2. Output the GARCH summary table and take note of the p-values of the lags. Based on the p-values, is the model a good fit (p < 0.05)?
# 3. Plot the 5-day forecast of the volatility.

# %%
from arch import arch_model

# %%
# Estimate a GARCH model:
model = arch_model(returns, mean="Zero", vol="GARCH", p=2, q=1)

# Fit the model
res = model.fit(disp="off")

# %%
# Summarize the model results
# YOUR CODE HERE!
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        Zero Mean - GARCH Model Results
# ...
# Dep. Variable:                 Settle   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -7461.93
# Distribution:                  Normal   AIC:                           14931.9
# Method:            Maximum Likelihood   BIC:                           14959.6
#                                         No. Observations:                 7514
# Date:                Wed, Oct 16 2019   Df Residuals:                     7510
# Time:                        15:31:46   Df Model:                            4
#                                Volatility Model
# ...
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# ...

# %% [markdown]
# #### The above results of the GARCH model have returned P Values <0.05 indicating that this model is a good fit.

# %%
# Find the last day of the dataset
last_day = returns.index.max().strftime('%Y-%m-%d')
last_day
# Out:
# '2019-10-15'

# %%
# Create a 5 day forecast of volatility
forecast_horizon = 5
# Start the forecast using the last_day calculated above
forecasts = res.forecast(start='2019-10-15', horizon=forecast_horizon)
forecasts
# Out:
# C:\Users\Michael\anaconda3\envs\dev\lib\site-packages\arch\__future__\_utility.py:21: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   FutureWarning,

# %%
# Annualize the forecast
intermediate = np.sqrt(forecasts.variance.dropna() * 252)
intermediate.head()
# Out:
#                  h.1       h.2       h.3      h.4       h.5
# Date
# 2019-10-15  7.434032  7.475729  7.516851  7.55741  7.597418

# %%
# Transpose the forecast so that it is easier to plot
final = intermediate.dropna().T
final.head()
# Out:
# Date  2019-10-15
# h.1     7.434032
# h.2     7.475729
# h.3     7.516851
# h.4     7.557410
# h.5     7.597418

# %%
# Plot the final forecast
final.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---

# %% [markdown]
# # Conclusions

# %% [markdown]
# Based on your time series analysis, would you buy the yen now?
#
# Is the risk of the yen expected to increase or decrease?
#
# Based on the model evaluation, would you feel confident in using these models for trading?
